# %%
from camcar_new import *
import numpy as np
import cv2 as cv
import matplotlib.pylab as plt


car = CamCar()

# %%
# y, 

img = car.get_prep_image(0, 480, 0, 640)
plt.imshow(img)
# Out:
# (480, 640, 3)

# %%
img = car.get_prep_image(100, 370, 0, 680)
plt.imshow(img)
# Out:
# (480, 640, 3)
