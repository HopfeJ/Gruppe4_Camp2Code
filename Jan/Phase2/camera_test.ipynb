# %%
import numpy as np
import cv2 as cv
import matplotlib.pylab as plt
from basisklassen_cam import Camera
import time

# %%
cam = Camera()



img = cam.get_frame()
plt.imshow(img)
     
    #if 0xff == ord('q'):
        #break


cam.release()
